# %% [markdown]
# # Classical baseline

# %%
from src.data.synthetic import *
from src.forecasting.demand import *
from src.optimization.problem import ProblemData
from src.optimization.classical import solve_cpsat
h=generate_arrivals(); E=generate_employees(8); S=generate_shifts(); R=build_staffing_requirements(forecast_next_day(h)); solve_cpsat(ProblemData(E,S,R))
